# %% [markdown]
# #### 05_RHI+GH_130418

# %% [markdown]
# ### построение модели на основе 2d чертежей с помощью GH
# #### - сортировка данных (работа со списками)
# #### - рекомендации по организации кода
# #### - работа с векторами

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('REqGUU8FXQg',width=420, height=270)
# Out:
#         <iframe
#             width="420"
#             height="270"
#             src="https://www.youtube.com/embed/REqGUU8FXQg"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('xmEmNuRXZt8',width=420, height=270)
